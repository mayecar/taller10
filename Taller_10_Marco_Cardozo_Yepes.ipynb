# %% [markdown]
# **Taller 1: Uso de Pandas**
#
# Nombre: Marco Yesid Cardozo Yepes
#
# Cédula: 1001283581

# %%
# !pip install sodapy

# %%
#Punto 1
#Cargue el dataset disponible en
#https://www.datos.gov.co/Econom-a-y- Finanzas/Tasa-de-Cambio-Representativa-del-Mercado-TRM/32sa-8pi3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sodapy import Socrata
cliente=Socrata('www.datos.gov.co', None)
result=cliente.get("32sa-8pi3")
df=pd.DataFrame.from_records(result)
df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#      valor unidad            vigenciadesde            vigenciahasta
# 0  4761.64    COP  2022-12-22T00:00:00.000  2022-12-22T00:00:00.000
# 1  4781.28    COP  2022-12-20T00:00:00.000  2022-12-20T00:00:00.000
# 2  4802.48    COP  2022-12-17T00:00:00.000  2022-12-19T00:00:00.000
# 3  4836.24    COP  2022-12-13T00:00:00.000  2022-12-13T00:00:00.000
# 4  4815.99    COP  2022-12-10T00:00:00.000  2022-12-12T00:00:00.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   valor          1000 non-null   object
#  1   unidad         1000 non-null   object
#  2   vigenciadesde  1000 non-null   object
#  3   vigenciahasta  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
#columna_numerica = pd.to_numeric(datos['limite_menor_cuantia'], errors='coerce')
#columna_numerica = columna_numerica.dropna().astype(float)
valor=pd.to_numeric(df['valor'],errors='coerce')
print(valor)
# Out:
# 0      4761.64
# 1      4781.28
# 2      4802.48
# 3      4836.24
# 4      4815.99
#         ...
# 995    1978.63
# 996    1993.85
# 997    1998.60
# 998    2017.38
# 999    2034.86
# Name: valor, Length: 1000, dtype: float64

# %%
#Punto 2
#Calcular
#a. Media
#b. Mediana
#c. Desviación estándar
#d. Máximo
#e. Mínimo
#f. Máximo
#g. Rango
print('El valor de la media es: ',round(np.mean(valor),2))
print('El valor de la mediana es: ',round(np.median(valor),2))
print('El valor de la desviación estandar es: ',round(np.std(valor),2))
print('El valor del máximo es: ',round(np.max(valor),2))
print('El valor del mínimo es: ',round(np.min(valor),2))
print('El valor del rango es: ',round(np.max(valor),)-round(np.min(valor),2))
# Out:
# El valor de la media es:  3042.38
# El valor de la mediana es:  2972.52
# El valor de la desviación estandar es:  730.32
# El valor del máximo es:  5061.21
# El valor del mínimo es:  1846.12
# El valor del rango es:  3214.88

# %%
#Punto 3
#Presentar el resumen de los datos numéricos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   valor          1000 non-null   object
#  1   unidad         1000 non-null   object
#  2   vigenciadesde  1000 non-null   object
#  3   vigenciahasta  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
df['Valor_n']=valor
df
# Out:
#        valor unidad            vigenciadesde            vigenciahasta  Valor_n
# 0    4761.64    COP  2022-12-22T00:00:00.000  2022-12-22T00:00:00.000  4761.64
# 1    4781.28    COP  2022-12-20T00:00:00.000  2022-12-20T00:00:00.000  4781.28
# 2    4802.48    COP  2022-12-17T00:00:00.000  2022-12-19T00:00:00.000  4802.48
# 3    4836.24    COP  2022-12-13T00:00:00.000  2022-12-13T00:00:00.000  4836.24
# 4    4815.99    COP  2022-12-10T00:00:00.000  2022-12-12T00:00:00.000  4815.99
# ..       ...    ...                      ...                      ...      ...
# 995  1978.63    COP  2014-03-26T00:00:00.000  2014-03-26T00:00:00.000  1978.63
# 996  1993.85    COP  2014-03-22T00:00:00.000  2014-03-25T00:00:00.000  1993.85
# 997   1998.6    COP  2014-03-21T00:00:00.000  2014-03-21T00:00:00.000  1998.60
# 998  2017.38    COP  2014-03-20T00:00:00.000  2014-03-20T00:00:00.000  2017.38
# 999  2034.86    COP  2014-03-19T00:00:00.000  2014-03-19T00:00:00.000  2034.86
#
# [1000 rows x 5 columns]

# %%
df.describe()
# Out:
#            Valor_n
# count  1000.000000
# mean   3042.376510
# std     730.689006
# min    1846.120000
# 25%    2500.497500
# 50%    2972.525000
# 75%    3646.340000
# max    5061.210000

# %%
#Punto 4
#Presentar la información general del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   valor          1000 non-null   object
#  1   unidad         1000 non-null   object
#  2   vigenciadesde  1000 non-null   object
#  3   vigenciahasta  1000 non-null   object
#  4   Valor_n        1000 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 39.2+ KB

# %% [markdown]
# **Análisis del DataSet.**
#
#
# Se evidencia que el dataset original no cuenta con los tipos datos semejantes a la descripción de la página de datos abiertos. Dado que la columana "valor" no es de tipo númerico sino de tipo "object".
# La operación que se se realizó fue hacer una conversión a números flotantes y luego adjuntarla al DataFrame.
# Respecto a los resultados del valor de la tasa de cambio que inicia desde el 19 de marzo de 2014 hasta el 22 de diciembre de 2022 se refleja un valor mínimo de 1846.12 y un valor máximo de 5061.21 con un promedio de 3042.37 pesos colombianos.

# %%
#Punto 5
#Hacer dos representaciones gráficas que sean acordes a la naturaleza de los datos
df.hist(bins=10,color='darkcyan',ec="gainsboro")
plt.title('Histograma de la variación del Dólar')
plt.xlabel('Pesos colombianos')
plt.show()

# %%
df.plot()
plt.title('Gráfica de la variación del dólar sin ordenar')
plt.xlabel('Tiempo')
plt.ylabel('Pesos')
plt.grid()
plt.show()

# %%
#Ordenar las fechas y valores del data Frame
data_o=df.sort_values(by=['vigenciadesde'])
valores=list(data_o['Valor_n'])
plt.plot(valores,'mediumspringgreen')
plt.title('Variación histórica del dólar')
plt.xlabel('Tiempo')
plt.ylabel('Pesos $')
plt.grid()
plt.show()

# %%
print(data_o.head(1))
# Out:
#        valor unidad            vigenciadesde            vigenciahasta  Valor_n
# 999  2034.86    COP  2014-03-19T00:00:00.000  2014-03-19T00:00:00.000  2034.86

# %%
print(data_o.tail())
# Out:
#      valor unidad            vigenciadesde            vigenciahasta  Valor_n
# 4  4815.99    COP  2022-12-10T00:00:00.000  2022-12-12T00:00:00.000  4815.99
# 3  4836.24    COP  2022-12-13T00:00:00.000  2022-12-13T00:00:00.000  4836.24
# 2  4802.48    COP  2022-12-17T00:00:00.000  2022-12-19T00:00:00.000  4802.48
# 1  4781.28    COP  2022-12-20T00:00:00.000  2022-12-20T00:00:00.000  4781.28
# 0  4761.64    COP  2022-12-22T00:00:00.000  2022-12-22T00:00:00.000  4761.64

# %%
#Punto 6
#Usando Socrata, Cargue un dataset que se encuentre en el portal de datos públicos de Colombia
#Se usa un dataset que tiene los precios de venta del combustible
#reportados por las Estaciones de Servicio (EDS) acorde al precio regulado o de mercado.
cliente2=Socrata('www.datos.gov.co', None)
result=cliente2.get("x6id-4v3g")
df_combus=pd.DataFrame.from_records(result)
df_combus.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   departamentocodigo departamentonombre municipiocodigo  \
# 0                 63            QUINDIO           63001
# 1                 63            QUINDIO           63001
# 2                 27              CHOCO           27430
# 3                 63            QUINDIO           63001
# 4                 27              CHOCO           27430
#
#               municipionombre  \
# 0                     ARMENIA
# 1                     ARMENIA
# 2  MEDIO BAUDO (PUERTO MELUK)
# 3                     ARMENIA
# 4  MEDIO BAUDO (PUERTO MELUK)
#
#                                               agente bandera  \
# 0  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 1  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 2            ESTACION DE SERVICIO AUTOMOTRIZ JZ No 2  TERPEL
# 3  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# ...

# %%
#Punto 7
#Realice las tareas de limpieza y transformación necesarias
#Limpieza-Quitar datos nulos
df_combus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   departamentocodigo  1000 non-null   object
#  1   departamentonombre  1000 non-null   object
#  2   municipiocodigo     1000 non-null   object
#  3   municipionombre     1000 non-null   object
#  4   agente              1000 non-null   object
#  5   bandera             1000 non-null   object
#  6   direccion           1000 non-null   object
#  7   producto            1000 non-null   object
#  8   precio              1000 non-null   object
#  9   estado              1000 non-null   object
#  10  fecharegistro       1000 non-null   object
# dtypes: object(11)
# memory usage: 86.1+ KB

# %%
 #Eliminar filas con dato nulos
df_auto=df_combus.dropna(axis=0, how='any')
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   departamentocodigo  1000 non-null   object
#  1   departamentonombre  1000 non-null   object
#  2   municipiocodigo     1000 non-null   object
#  3   municipionombre     1000 non-null   object
#  4   agente              1000 non-null   object
#  5   bandera             1000 non-null   object
#  6   direccion           1000 non-null   object
#  7   producto            1000 non-null   object
#  8   precio              1000 non-null   object
#  9   estado              1000 non-null   object
#  10  fecharegistro       1000 non-null   object
# dtypes: object(11)
# memory usage: 86.1+ KB

# %% [markdown]
# **No se encontraron datos nulos en el dataset.**

# %%
df_combus.describe()
# Out:
#        departamentocodigo departamentonombre municipiocodigo municipionombre  \
# count                1000               1000            1000            1000
# unique                 31                 31             259             257
# top                    52             NARIÑO           11001     BOGOTA D.C.
# freq                  136                136              35              35
#
#                                agente bandera          direccion  \
# count                            1000    1000               1000
# unique                            465      19                467
# top     ESTACION DE SERVICIO AGRICOLA  TERPEL  VEREDA SANTA RITA
# freq                                6     283                  5
#
#                             producto precio estado            fecharegistro
# count                           1000   1000   1000                     1000
# unique                            10    487      1                      234
# ...

# %%
df_combus.head()
# Out:
#   departamentocodigo departamentonombre municipiocodigo  \
# 0                 63            QUINDIO           63001
# 1                 63            QUINDIO           63001
# 2                 27              CHOCO           27430
# 3                 63            QUINDIO           63001
# 4                 27              CHOCO           27430
#
#               municipionombre  \
# 0                     ARMENIA
# 1                     ARMENIA
# 2  MEDIO BAUDO (PUERTO MELUK)
# 3                     ARMENIA
# 4  MEDIO BAUDO (PUERTO MELUK)
#
#                                               agente bandera  \
# 0  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 1  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 2            ESTACION DE SERVICIO AUTOMOTRIZ JZ No 2  TERPEL
# 3  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 4            ESTACION DE SERVICIO AUTOMOTRIZ JZ No 2  TERPEL
#
# ...

# %%
#Revisar si hay registros duplicados
print(df_combus.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# **No se encontraron registros duplicados**

# %%
df_combus.drop_duplicates(inplace = True)
df_combus
# Out:
#     departamentocodigo departamentonombre municipiocodigo  \
# 0                   63            QUINDIO           63001
# 1                   63            QUINDIO           63001
# 2                   27              CHOCO           27430
# 3                   63            QUINDIO           63001
# 4                   27              CHOCO           27430
# ..                 ...                ...             ...
# 995                 18            CAQUETA           18150
# 996                 70              SUCRE           70742
# 997                 25       CUNDINAMARCA           25394
# 998                 52             NARIÑO           52786
# 999                 19              CAUCA           19532
#
#                 municipionombre  \
# 0                       ARMENIA
# 1                       ARMENIA
# 2    MEDIO BAUDO (PUERTO MELUK)
# 3                       ARMENIA
# 4    MEDIO BAUDO (PUERTO MELUK)
# ..                          ...
# 995        CARTAGENA DEL CHAIRA
# ...

# %%
df_combus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   departamentocodigo  1000 non-null   object
#  1   departamentonombre  1000 non-null   object
#  2   municipiocodigo     1000 non-null   object
#  3   municipionombre     1000 non-null   object
#  4   agente              1000 non-null   object
#  5   bandera             1000 non-null   object
#  6   direccion           1000 non-null   object
#  7   producto            1000 non-null   object
#  8   precio              1000 non-null   object
#  9   estado              1000 non-null   object
#  10  fecharegistro       1000 non-null   object
# dtypes: object(11)
# memory usage: 93.8+ KB

# %%
#Punto 8
#Presentar el dataset, mostrando datos estadísticos y gráficas
df_combus.head()
var=list((df_combus['precio']))
precio=[]
for i in range(len(var)):
  precio.append(int(var[i]))

precio_a=np.array(precio)
print('La media del precio de combustible es: ', round(np.mean(precio_a),2))
print('El valor de la mediana del precio de combustible es: ',round(np.median(precio_a),2))
print('El valor de la desviación estandar del precio de combustible es: ',round(np.std(precio_a),2))
print('El valor del máximo del precio de combustible es: ',round(np.max(precio_a),2))
print('El valor del mínimo del precio de combustible es: ',round(np.min(precio_a),2))
print('El valor del rango del precio de combustible es: ',round(np.max(precio_a),)-round(np.min(precio_a),2))
# Out:
# La media del precio de combustible es:  8287.75
# El valor de la mediana del precio de combustible es:  8286.0
# El valor de la desviación estandar del precio de combustible es:  1369.11
# El valor del máximo del precio de combustible es:  18000
# El valor del mínimo del precio de combustible es:  3800
# El valor del rango del precio de combustible es:  14200

# %% [markdown]
# **Analisis de los precios del combustible en Colombia.**
#
# La media del precio de combustible a nivel nacional de las diferentes estaciones de servicio es de 8287.75 pesos desde enero de 2015 hasta marzo de 2018, lo cual refleja un precio del combustible estable en los 3 años de estudio pese a tener picos de 18000 pesos y bajos de 3800 pesos.

# %%
#Gráfica del histograma de precios
plt.hist(precio_a, bins=10,color='midnightblue')
plt.axvline(np.mean(precio_a), ymin=0.0, ymax=0.9,color='r')
plt.title('Histograma de los precios del combustible en Colombia')
plt.xlabel('Pesos colombianos')
plt.grid()
plt.show()

# %%
#Graficas el diagrama de caja de los precios
plt.boxplot(precio_a)
plt.title('Diagrama de caja para precio del combustible')
plt.ylabel('Precios')
plt.grid()
plt.show()

# %%
#Analisis de las banderas de los precios del combustible
df_bandera=df_combus[['bandera']]
df_bandera.head()
# Out:
#   bandera
# 0  TERPEL
# 1  TERPEL
# 2  TERPEL
# 3  TERPEL
# 4  TERPEL

# %%
df_bandera.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   bandera  1000 non-null   object
# dtypes: object(1)
# memory usage: 15.6+ KB

# %%
df_bandera.tail()
# Out:
#       bandera
# 995    TERPEL
# 996      SAVE
# 997    TEXACO
# 998    TEXACO
# 999  PETROMIL

# %%
lista_bandera=list(df_bandera['bandera'])
for i in lista_bandera:
  print(i)
# Out:
# TERPEL
# TERPEL
# TERPEL
# TERPEL
# TERPEL
# BIOMAX
# BIOMAX
# BIOMAX
# TERPEL
# TERPEL
# TERPEL
# TERPEL
# TERPEL
# TERPEL
# TERPEL
# PETROBRAS
# BIOMAX
# PETROBRAS
# BIOMAX
# TERPEL
# TERPEL
# TERPEL
# TERPEL
# TERPEL
# TEXACO
# TEXACO
# TEXACO
# MOBIL
# TERPEL
# BIOMAX
# BIOMAX
# MOBIL
# MOBIL
# BIOMAX
# BIOMAX
# TERPEL
# TERPEL
# BIOMAX
# PUMA
# PUMA
# TERPEL
# TERPEL
# MOBIL
# MOBIL
# MOBIL
# TERPEL
# TERPEL
# TERPEL
# BIOMAX
# BIOMAX
# TERPEL
# TERPEL
# TEXACO
# TEXACO
# BIOMAX
# BIOMAX
# BIOMAX
# MOBIL
# MOBIL
# MOBIL
# PETROMIL
# PETROMIL
# ZEUSS
# ZEUSS
# MOBIL
# MOBIL
# OCTANO
# OCTANO
# TEXACO
# TEXACO
# TERPEL
# BIOMAX
# MOBIL
# PETROMIL
# BIOMAX
# MOBIL
# MOBIL
# MOBIL
# PETROMIL
# MOBIL
# BIOMAX
# BIOMAX
# PETROBRAS
# PETROBRAS
# TEXACO
# PETROMIL
# PETROMIL
# ECOS
# BIOMAX
# BIOMAX
# PUMA
# PUMA
# BIOMAX
# BIOMAX
# TERPEL
# TEXACO
# TEXACO
# TEXACO
# TERPEL
# OCTANO
# OCTANO
# BIOMAX
# BIOMAX
# PETROMIL
# TERPEL
# TERPEL
# BRIO
# BRIO
# MOBIL
# MOBIL
# MOBIL
# TERPEL
# ...

# %%
df_bandera.describe()
# Out:
#        bandera
# count     1000
# unique      19
# top     TERPEL
# freq       283

# %%
#Vamos a contar las diferentes banderas (estaciones de servicio)
def contar(n, vec):
  '''Para esta funcion n es el numero a contar y vec es la lista donde contar '''
  count=0
  for i in vec:
    if i==n:
      count+=1
  return count

# %%
print('TERPEL aparece: ',contar('TERPEL', lista_bandera))
print('SAVE aparece: ',contar('SAVE', lista_bandera))
print('BIOMAX aparece: ',contar('BIOMAX', lista_bandera))
print('TEXACO aparece: ',contar('TEXACO', lista_bandera))
print('AYATAWACOOP aparece: ',contar('AYATAWACOOP', lista_bandera))
print('PETROMIL aparece: ',contar('PETROMIL', lista_bandera))
print('ESSO aparece: ',contar('ESSO', lista_bandera))
print('COOMULPINORT aparece: ',contar('COOMULPINORT', lista_bandera))
print('MOBIL aparece: ',contar('MOBIL', lista_bandera))
print('ZEUSS aparece: ',contar('ZEUSS', lista_bandera))
print('BRIO aparece: ',contar('BRIO', lista_bandera))
print('ECOS aparece: ',contar('ECOS', lista_bandera))
print('DISCOWACOOP aparece: ',contar('DISCOWACOOP', lista_bandera))
print('ZAPATA Y VELASQUEZ aparece: ',contar('ZAPATA Y VELASQUEZ', lista_bandera))
print('PUMA aparece: ',contar('PUMA', lista_bandera))
print('GULF aparece: ',contar('GULF', lista_bandera))
print('CASAMOTOR aparece: ',contar('CASAMOTOR', lista_bandera))
print('PETROBRAS aparece: ',contar('PETROBRAS', lista_bandera))
print('OCTANO aparece: ',contar('OCTANO', lista_bandera))


aux=[contar('TERPEL', lista_bandera), contar('SAVE', lista_bandera),contar('BIOMAX', lista_bandera),
     contar('TEXACO', lista_bandera),contar('AYATAWACOOP', lista_bandera), contar('PETROMIL', lista_bandera),
     contar('ESSO', lista_bandera) , contar('COOMULPINORT', lista_bandera),contar('MOBIL', lista_bandera),
     contar('ZEUSS', lista_bandera),contar('BRIO', lista_bandera),contar('ECOS', lista_bandera),contar('DISCOWACOOP', lista_bandera),
     contar('ZAPATA Y VELASQUEZ', lista_bandera),contar('PUMA', lista_bandera),contar('GULF', lista_bandera),contar('CASAMOTOR', lista_bandera),
     contar('PETROBRAS', lista_bandera),contar('OCTANO', lista_bandera)]

print(aux)
print('--------------------------------')
print('La suma total es de: ',sum(aux))
# Out:
# TERPEL aparece:  283
# SAVE aparece:  11
# BIOMAX aparece:  257
# TEXACO aparece:  102
# AYATAWACOOP aparece:  34
# PETROMIL aparece:  111
# ESSO aparece:  2
# COOMULPINORT aparece:  12
# MOBIL aparece:  60
# ZEUSS aparece:  40
# BRIO aparece:  5
# ECOS aparece:  19
# DISCOWACOOP aparece:  7
# ZAPATA Y VELASQUEZ aparece:  5
# PUMA aparece:  16
# GULF aparece:  3
# CASAMOTOR aparece:  7
# PETROBRAS aparece:  16
# OCTANO aparece:  10
# [283, 11, 257, 102, 34, 111, 2, 12, 60, 40, 5, 19, 7, 5, 16, 3, 7, 16, 10]
# --------------------------------
# La suma total es de:  1000

# %%
num_bandera=[]
for i in range(len(lista_bandera)):
  num_bandera.append(contar(lista_bandera[i],lista_bandera))

print(num_bandera)
print(len(num_bandera))
# Out:
# [283, 283, 283, 283, 283, 257, 257, 257, 283, 283, 283, 283, 283, 283, 283, 16, 257, 16, 257, 283, 283, 283, 283, 283, 102, 102, 102, 60, 283, 257, 257, 60, 60, 257, 257, 283, 283, 257, 16, 16, 283, 283, 60, 60, 60, 283, 283, 283, 257, 257, 283, 283, 102, 102, 257, 257, 257, 60, 60, 60, 111, 111, 40, 40, 60, 60, 10, 10, 102, 102, 283, 257, 60, 111, 257, 60, 60, 60, 111, 60, 257, 257, 16, 16, 102, 111, 111, 19, 257, 257, 16, 16, 257, 257, 283, 102, 102, 102, 283, 10, 10, 257, 257, 111, 283, 283, 5, 5, 60, 60, 60, 283, 283, 11, 11, 11, 11, 111, 5, 40, 40, 111, 111, 283, 283, 7, 7, 16, 16, 111, 7, 7, 283, 283, 283, 102, 102, 102, 11, 11, 11, 40, 40, 40, 257, 257, 283, 283, 10, 10, 283, 283, 10, 10, 60, 60, 60, 257, 257, 16, 16, 16, 102, 283, 283, 19, 283, 283, 19, 19, 283, 283, 257, 257, 283, 283, 283, 283, 283, 283, 283, 283, 283, 102, 102, 283, 283, 283, 283, 257, 257, 257, 257, 34, 34, 111, 111, 60, 111, 60, 60, 111, 102, 283, 257, 102, 283, 34, 257, 283, 257, 34, 283, 16, 16, 283, 2
# ...

# %%
#Diagrama de Barras
categoria=['TERPEL','SAVE','BIOMAX','TEXACO','AYATAWACOOP','PETROMIL','ESSO','COOMULPINORT','MOBIL','ZEUSS',
           'BRIO','ECOS','DISCOWACOOP','ZAPATA Y VELASQUEZ','PUMA','GULF','CASAMOTOR','PETROBRAS','OCTANO']
plt.barh(categoria,aux,color='palegreen')
plt.xlabel('N° de repeticiones')
plt.ylabel('Bandera')
plt.title('Análisis sobre las banderas (EDS) de combustibles')
plt.grid()
plt.show()

# %%
mayor_5=[283,257,111,102,60]
percent=sum(mayor_5)/len(aux)
print('El porcentaje de las 5 mayores banderas es de: ',round(percent,2))
# Out:
# El porcentaje de las 5 mayores banderas es de:  42.79

# %% [markdown]
# Las 5 mayores estaciones de servicio de combustible a nivel nacional son de las banderas de Terpel, Biomax, Petromil, Texaco y Mobil que representan alrededor del 42,79% del total de banderas .

# %%
len(num_bandera)
# Out:
# 1000

# %%
#aux_=pd.Series(num_clase)
#df_clase['Repite']=aux_
#df_clase

# %%
#Punto 9
#Se debe incluir mínimo una tabla pivote y una agrupación
df_combus.head()
# Out:
#   departamentocodigo departamentonombre municipiocodigo  \
# 0                 63            QUINDIO           63001
# 1                 63            QUINDIO           63001
# 2                 27              CHOCO           27430
# 3                 63            QUINDIO           63001
# 4                 27              CHOCO           27430
#
#               municipionombre  \
# 0                     ARMENIA
# 1                     ARMENIA
# 2  MEDIO BAUDO (PUERTO MELUK)
# 3                     ARMENIA
# 4  MEDIO BAUDO (PUERTO MELUK)
#
#                                               agente bandera  \
# 0  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 1  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 2            ESTACION DE SERVICIO AUTOMOTRIZ JZ No 2  TERPEL
# 3  ESTACION DE SERVICIO AUTOMOTRIZ TERPEL CENTENARIO  TERPEL
# 4            ESTACION DE SERVICIO AUTOMOTRIZ JZ No 2  TERPEL
#
# ...

# %%
df_combus.pivot_table(values='precio', index='departamentonombre', columns=['producto'], aggfunc='count')
# Out:
# producto            ACEM - DIESEL ECOLOGICO  BIOACEM AL 9%  \
# departamentonombre
# AMAZONAS                                NaN            NaN
# ANTIOQUIA                               NaN            NaN
# ARAUCA                                  NaN            NaN
# ATLANTICO                               NaN            NaN
# BOGOTA D.C.                             NaN            6.0
# BOLIVAR                                 NaN            NaN
# BOYACA                                  NaN           11.0
# CALDAS                                  NaN            NaN
# CAQUETA                                 NaN            NaN
# CASANARE                                NaN            1.0
# CAUCA                                   NaN            NaN
# CESAR                                   NaN            NaN
# CHOCO                                   NaN            NaN
# CORDOBA                                 NaN            NaN
# CUNDINAMARCA                            NaN           14.0
# ...

# %%
df_combus.groupby(df_combus['departamentonombre']).count()[['estado']]
# Out:
#                     estado
# departamentonombre
# AMAZONAS                 3
# ANTIOQUIA               61
# ARAUCA                   4
# ATLANTICO               40
# BOGOTA D.C.             35
# BOLIVAR                 37
# BOYACA                  41
# CALDAS                  15
# CAQUETA                 32
# CASANARE                 7
# CAUCA                   47
# CESAR                   20
# CHOCO                   27
# CORDOBA                 30
# CUNDINAMARCA            65
# GUAVIARE                33
# HUILA                   18
# LA GUAJIRA              41
# MAGDALENA               43
# META                    57
# NARIÑO                 136
# NORTE DE SANTANDER      12
# PUTUMAYO                 6
# QUINDIO                  6
# RISARALDA                4
# SANTANDER               30
# SUCRE                   30
# TOLIMA                  41
# VALLE DEL CAUCA         64
# VAUPES                   7
# VICHADA                  8

# %%
df_combus.groupby(df_combus['departamentonombre']).count()['agente']
# Out:
# departamentonombre
# AMAZONAS                3
# ANTIOQUIA              61
# ARAUCA                  4
# ATLANTICO              40
# BOGOTA D.C.            35
# BOLIVAR                37
# BOYACA                 41
# CALDAS                 15
# CAQUETA                32
# CASANARE                7
# CAUCA                  47
# CESAR                  20
# CHOCO                  27
# CORDOBA                30
# CUNDINAMARCA           65
# GUAVIARE               33
# HUILA                  18
# LA GUAJIRA             41
# MAGDALENA              43
# META                   57
# NARIÑO                136
# NORTE DE SANTANDER     12
# PUTUMAYO                6
# QUINDIO                 6
# RISARALDA               4
# SANTANDER              30
# SUCRE                  30
# TOLIMA                 41
# VALLE DEL CAUCA        64
# VAUPES                  7
# VICHADA                 8
# Name: agente, dtype: int64

# %%
lis=list(df_combus['departamentonombre'])
for i in lis:
  print(i)

# %%
#Punto 10
#Todas las graficas deben ser explicadas
#Diagrama de Barras
categoria=['TERPEL','SAVE','BIOMAX','TEXACO','AYATAWACOOP','PETROMIL','ESSO','COOMULPINORT','MOBIL','ZEUSS',
           'BRIO','ECOS','DISCOWACOOP','ZAPATA Y VELASQUEZ','PUMA','GULF','CASAMOTOR','PETROBRAS','OCTANO']
plt.barh(categoria,aux,color='lightcoral')
plt.xlabel('N° de repeticiones')
plt.ylabel('Bandera')
plt.title('Análisis sobre las banderas (EDS) de combustibles')
plt.grid()
plt.show()

# %% [markdown]
# **Análsis de la gráfica**
#
# *   La bandera más común en la gráfica y tabla es la de Terpel con 283 estaciones de servicio a nivel nacional, seguido por Biomax con 257 estaciones de servicio y Petromil con 111 estaciones de servicio
#
# * Las banderas menos comunes es la de Zapata y Velasquez, Brio con 5 estaciones de servicio, seguido de Gulf con 3 estaciones de servicio y Esso con 2 estaciones de servicio.

# %% [markdown]
# **Analisis desde Chat GPT**
#
# TERPEL es la empresa más mencionada con 283 apariciones en algún contexto. Esto sugiere que TERPEL podría ser una empresa prominente o ampliamente conocida en el sector de los combustibles o la industria petrolera.
#
# BIOMAX también es muy mencionada con 257 apariciones, lo que indica que es otra empresa relevante o de gran importancia en el ámbito petrolero o de combustibles.
#
# TEXACO y PETROMIL también reciben un número considerable de menciones (102 y 111 veces, respectivamente).
#
# Algunas empresas como ESSO, GULF y BRIO tienen un número de menciones bastante bajo, lo que podría sugerir que son menos conocidas o menos influyentes en el contexto en el que se presentan.
#
# AYATAWACOOP, ZEUSS, DISCOWACOOP, ZAPATA Y VELASQUEZ, entre otras, también tienen menos apariciones en comparación con las principales empresas.
# Es importante tener en cuenta que este análisis se basa únicamente en la cantidad de menciones en la lista dada y no proporciona información sobre el tamaño, la influencia o la posición financiera de estas empresas en la realidad. Además, algunas de estas empresas pueden estar operando en diferentes regiones y, por lo tanto, su relevancia puede variar según la ubicación geográfica.

# %%
print(aux)
print(categoria)
# Out:
# [283, 11, 257, 102, 34, 111, 2, 12, 60, 40, 5, 19, 7, 5, 16, 3, 7, 16, 10]
# ['TERPEL', 'SAVE', 'BIOMAX', 'TEXACO', 'AYATAWACOOP', 'PETROMIL', 'ESSO', 'COOMULPINORT', 'MOBIL', 'ZEUSS', 'BRIO', 'ECOS', 'DISCOWACOOP', 'ZAPATA Y VELASQUEZ', 'PUMA', 'GULF', 'CASAMOTOR', 'PETROBRAS', 'OCTANO']

# %%
#Graficas el diagrama de caja
plt.boxplot(precio_a)
plt.title('Diagrama de caja para precio del combustible')
plt.ylabel('Precios')
plt.grid()
plt.show()

# %% [markdown]
# Este diagrama de caja o boxplot muestra que los precios de los combustibles a nivel nacional se concentran en los 8280 pesos aproximadamente y que los precios no varian tanto a pesar de que el dataset contiene información de los 32 departamentos de Colombia. Sin embargo, existen algunos precios altos atipicos que se encuentran en 14000 y 18000 pesos y precios bajos atipicos de 3800 y 4000 que pueden ser explicados por las siguientes razones:
#
#
# 1.   Ubicación geográfica de las estaciones de servicio (banderas).
# 2.   Altos costos de transporte (vías, clima,impuestos y aránceles) para llevar el combustible al lugar de destino que se reflejarian en el precio al consumidor.

# %%
#Grafica del histograma
plt.hist(precio_a, bins=10,color='aquamarine')
plt.axvline(np.mean(precio_a), ymin=0.0, ymax=0.9,color='r')
plt.title('Histograma de los precios del combustible en Colombia')
plt.xlabel('Pesos colombianos')
plt.grid()
plt.show()

# %% [markdown]
# El histograma representa los diferentes precios de los combustibles en el dataset, se encuentra que la concentración de precios esta alrededor de los 8000 a 9000 pesos colombianos a nivel nacional para el periodo de 2015 a 2018.Sin embargo, es necesario tener en cuenta que el combustible en Colombia tiene un subsidio alrededor de 6000 a 7000 pesos, siendo uno de los más altos a nivel mundial, sin este el precio estaria en 14000 a 15000 pesos colombianos. Esto tienen algunas ventajas en la economía como la preservación del poder adquisitivo de los colombianos cotidianamente, sin embargo, este tipo de subsidios generan fallas de mercado que de no ser corregidas con el paso del tiempo terminaran afectando el bienestar de la sociedad en general, como por ejemplo el uso excesivo de combustible a un bajo precio conlleva aún más a la contaminación del medio ambiente o siendo perjudicial en las finanzas públicas del país como se ve actualmente, dado que se vuelve insostenible mantener este tipo de subsidios.
